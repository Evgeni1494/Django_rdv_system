# %% [markdown]
# Un coach en développement personnel souhaite un système de prise de rendez-vous automatique en ligne.
# Aidez-le à l'aide de vos connaissances sur python et Django.
#
# ​
#
# Le client souhaite les fonctionnalités suivantes :
#
#     - une page d'accueil qui présente son travail
#     - un système d'authentification afin que lui et ses utilisateurs puissent se connecter au site.
#     - un système de prise de rdv.
#     - un historique des séances précédentes avec chaque client avec la possibilité pour le coach de conserver des notes sur chacune des séances
#
# ​
#
# Pour la prise de rendez-vous :
#
#     - le coach ne peut être dans deux rendez-vous en même temps
#     - il faut au moins 10mins entre deux rdv
#     - les rdv ne peuvent être pris que de 9h à 12h30 et de 13h30 à 17h
#     - lors de la prise de rdv, le client peut entrer dans un formulaire l'objet de la séance

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------
# ### Page Accueil
#     - NavBar
#         - A propos.
#         - Contact.
#         - Prendre un RDV.
#         - Inscription.
#         - Connexion.
#     - One page sur les bien étres.
#     - Presentation en bref du travaille.
#
# ---------------------------------------------------------------------------------------------------------------------------------
# ### Authentification
#
# #### Compte Admin
#     - Un compte "Admin" pour le coach.
#         - Une page avec les RDV avenir (calendrier ?).
#         - Une page avec la liste des clients.
#             - Rechercher un client dans la liste.
#             - Acces a chaque profil de client.
#                 - Profil contient :
#                     - Historique des RDV
#                     - Notes des séances.
#                     - Possibilité de laisser une note.
#         - Gestion du compte (comme celle du client)
# #### Compte Client
#     - Creation de compte client.
#         - Nom
#         - Prenom
#         - Date de naissance
#         - Mail
#         - Téléphone
#         - Mot de Passe.
#     - Connexion sur le site.
#         - Epace perso.
#         - Géstion du compte.
#             - Modifier mot de passe.
#             - Modifier Email
#             - Modifier Téléphone
#             - Reinitialisation du mot de passe.
# ------------------------------------------------------------------------------------------------------------------------------------
# ### Prise de rdv
#
#     - Si non-connecté
#         - propose de crée un compte maintenant.
#             - Lien de rédirection vers la page inscription
#     - Si connecté
#         - acces a l'intérface de prise de rdv.
#
#     - Choix de la date.
#         - Liste des creneaux libres.
#     - Formulaire pré-rempli avec les données du compte client.
#     - Un champ "Objet" a remplir obligatoire.
#     - Un champ "Déscription" a remplir optionnel
#
#
#     - Une fois le formulaire rempli click sur "Confirmer"
#
#     - Pas 2 RDV en meme temps.
#     - Les RDV sont possible que de [9h a 12h30] et de [13h30 a 17h]
# -----------------------------------------------------------------------------------------------------------------------------
# ### Historique des séances
